# %%
판다스 원핫 인코딩

# %%
sklearn

# %% [markdown]
# 정규화
# - https://velog.io/@jiazzang/%EB%8D%B0%EC%9D%B4%ED%84%B0-%EC%A0%84%EC%B2%98%EB%A6%AC-%EB%8D%B0%EC%9D%B4%ED%84%B0-%EC%8A%A4%EC%BC%80%EC%9D%BC%EB%A7%81StandardScaler-MinMaxScaler-Robust (정규화 개념)
# - https://wikidocs.net/89704 (로버스트 스케일러
# )

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# mae

# %%
grid search cv

다양한 성능 평가 가능성이 나올 듯
